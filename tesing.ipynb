# %% [markdown]
# <a href="https://colab.research.google.com/github/molluIdontknow/test/blob/develop/tesing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi")
print("good")
print("identity")
print("gg")
a=5
# Out:
# hi
# good
# identity
# gg
